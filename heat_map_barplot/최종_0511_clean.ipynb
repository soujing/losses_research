# %% [markdown]
# # 데이터 load(과정 필요 없음)

# %%
# import pandas as pd
# import os
# # list_dir = os.listdir("/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/")
 
# # def func(data):
# #     name_csv = []
# #     for d in data:
# #         if "really_jinshim" in d:
# #             name_csv.append(d)
# #         elif "last_data_0416.csv" == d:
# #             name_csv.append(d)
# #         else:
# #             pass
# #     return name_csv
# # need_data_list = func(list_dir)

# %%
# # beg_add = pd.read_csv("/project/ahnailab/jsj0414/지역포함_0113/last/lasting_alls.csv")
# need_data_list = []
# need_data_list.extend([
#     "/project/ahnailab/jsj0414/지역포함_0113/last/lasting_alls.csv",
#     "/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/last_data_0416.csv",
#     "/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/really_jinshim_last_wound_3_adding.csv",
#             "/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/really_jinshim_last_malignant_adding.csv",
#     #         "/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/adding_data/ISIC_add.csv",
#     #         "/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/adding_data/Kvasir_add.csv",
#     #         "/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/adding_data/malignant1.csv",
#     #         "/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/adding_data/wound_add.csv"
# ])
# # 파일 읽어서 리스트에 저장
# dfs = [pd.read_csv(file) for file in need_data_list]

# # 전체 concat
# merged_df = pd.concat(dfs, ignore_index=True)

# all_data = merged_df.reset_index(drop=True)

# %%
# all_data = all_data[all_data.columns[1::]]
# all_data

# %%
# all_data = all_data[all_data['model_name'] != 'SegResNet']
# all_data = all_data[all_data['model_name'] != 'SegNet']
# all_data = all_data[~all_data['loss_name'].str.contains("in", na=False)]
# all_data = all_data[~all_data['loss_name'].str.contains("Multi", na=False)]
# all_data = all_data[all_data['loss_name'] != 'IoUWithTVLoss']
# all_data = all_data[all_data['loss_name'] != 'BCEWithTVLoss']
# all_data = all_data[all_data['model_name'] != 'DuckNet']
# # all_data = all_data[all_data['model_name'] != 'ColonFormer'] # ColonSegNet	
# # all_data = all_data[all_data['model_name'] != 'caranet'] # caranet	
# # all_data = all_data[all_data['model_name'] != 'ColonSegNet'] # ColonSegNet	
# # all_data = all_data[all_data['model_name'] != 'FCN'] # caranet	
# # all_data = all_data[all_data['model_name'] != 'FAT_Net'] # caranet	
# all_data["data_name"] = all_data["data_name"].str.replace("-2017", "", regex=False)

# # 인덱스 초기화
# all_data = all_data.reset_index(drop=True)

# %%
# loss_use = ['IoULoss', 'DiceLoss', 'BCELoss', 'FocalLoss', 'IoUDiceLoss', 'IoUBCELoss', 'IoUFocalLoss', 
# 'DiceBCELoss', 'DiceFocalLoss', 'BCEFocalLoss', 'DiceWithContextualLoss', 'IoUWithContextualLoss', 
# 'FocalWithContextualLoss', 'BCEWithContextualLoss', 'IoUWithTV_tar_Loss', 'FocalWithTVLoss_tar',
#  'BCEWithTVLoss_tar', 'DiceWithTVLoss_tar', 'IoUWithSSIMLoss', 'DiceWithSSIMLoss', 'BCEWithSSIMLoss', 
# 'FocalWithSSIMLoss', 'IoUWithEdgeLoss', 'DiceWithEdgeLoss', 'FocalWithEdgeLoss', 'BCEWithEdgeLoss',
# 'FocalWithGaussianLoss', 'IoUWithGaussianLoss', 'BCEWithGaussianLoss', 'DiceWithGaussianLoss', 
# 'FocalWithRegionWeighting', 'DiceWeightedLoss', 'BCEWeightedLoss', 'IoUWeightedLoss']


# new_loss = ['DiceWithContextualLoss', 'IoUWithContextualLoss', 
# 'FocalWithContextualLoss', 'BCEWithContextualLoss', 'IoUWithTV_tar_Loss', 'FocalWithTVLoss_tar',
#  'BCEWithTVLoss_tar', 'DiceWithTVLoss_tar', 'IoUWithSSIMLoss', 'DiceWithSSIMLoss', 'BCEWithSSIMLoss', 
# 'FocalWithSSIMLoss', 'IoUWithEdgeLoss', 'DiceWithEdgeLoss', 'FocalWithEdgeLoss', 'BCEWithEdgeLoss',
# 'FocalWithGaussianLoss', 'IoUWithGaussianLoss', 'BCEWithGaussianLoss', 'DiceWithGaussianLoss', 
# 'FocalWithRegionWeighting', 'DiceWeightedLoss', 'BCEWeightedLoss', 'IoUWeightedLoss']

# pres_loss = ['IoULoss', 'DiceLoss', 'BCELoss', 'FocalLoss', 'IoUDiceLoss', 'IoUBCELoss', 'IoUFocalLoss', 
# 'DiceBCELoss', 'DiceFocalLoss', 'BCEFocalLoss']
# print(f"present_loss_count : {len(pres_loss)}\n present_all_loss : {pres_loss}\n")
# print(f"all_loss_count : {len(loss_use)}\n using_all_loss : {loss_use} \n new_loss_count : {len(new_loss)}\n using_new loss : {new_loss} \n ")

# %%
# import numpy as np
# # np.unique(all_data["model_name"])
# all_data = all_data[all_data['model_name'].str.contains("ColonFormer|EMCADNet|ESFPNet|FCBFormer|caranet", regex=True, na=False)]
# all_data = all_data.reset_index(drop=True)

# %%
# all_data["model_name"].unique()

# %%
testing = all_data.groupby(["data_name", "model_name", "loss_name"])
testing = testing['iter'].agg(['count'])
testing[testing["count"].values<5]

# %%
all_data[
        (all_data["data_name"] == 'breast-cancer-benign') &
        (all_data["model_name"] == 'ColonFormer') &
        (all_data["loss_name"] == 'BCEWithGaussianLoss')
    ]

# %%
all_data[
        (all_data["data_name"] == 'breast-cancer-benign') &
        (all_data["model_name"] == 'EMCADNet') &
        (all_data["loss_name"] == 'BCEWithEdgeLoss')
    ]

# %%
testing = all_data.groupby(["data_name", "model_name", "loss_name"])
testing = testing['iter'].agg(['count'])
less_d = testing[testing["count"].values < 5]

less_loss_idx = []

for data, model, loss in less_d.index:
    datas = all_data[
        (all_data["data_name"] == data) &
        (all_data["model_name"] == model) &
        (all_data["loss_name"] == loss)
    ]
    idxs = list(datas.index)
    print(f"{data, model, loss}", idxs)
    less_loss_idx.extend(idxs)  # 여러 인덱스를 계속 누적

# 한꺼번에 제거
all_data = all_data.drop(labels = less_loss_idx,axis = 0)

# 인덱스 초기화
all_data = all_data.reset_index(drop=True)

# %%
testing = all_data.groupby(["data_name", "model_name", "loss_name"])
testing = testing['iter'].agg(['count'])
testing[testing["count"].values<5]

# %%
testing = all_data.groupby(["data_name", "model_name", "loss_name"])
testing = testing['iter'].agg(['count'])
over_d = testing[testing["count"].values>5]
over_d

# %%
all_data = all_data.reset_index(drop=True)

testing = all_data.groupby(["data_name", "model_name", "loss_name"])
testing = testing['iter'].agg(['count'])
over_d = testing[testing["count"].values>5]
# over_d.index[-1]

over_loss_idx = []

for data, model, loss in over_d.index:
    all_data = all_data.reset_index(drop=True)

    # 해당 그룹 필터링
    loss_data = all_data[
        (all_data["data_name"] == data) &
        (all_data["model_name"] == model) &
        (all_data["loss_name"] == loss)
    ]

    loss_data = loss_data.reset_index()  # drop=False (기본), 원래 인덱스 보존됨
    d_len = len(loss_data)

    found = False

    for i in range(d_len - 4):  # 슬라이딩 윈도우
        check_seq = loss_data.loc[i:i+4, "iter"].tolist()

        if check_seq == [0, 1, 2, 3, 4]:
            keep_indices = loss_data.loc[i:i+4, "index"].tolist()
            drop_indices = [idx for idx in loss_data["index"] if idx not in keep_indices]

            all_data = all_data.drop(index=drop_indices).reset_index(drop=True)
            found = True
            break  # 더 이상 이 그룹은 안 봐도 됨

    # # 만약 0~4 연속 구간이 아예 없으면, 그룹 전체 제거
    # if not found:
        # all_data = all_data.drop(index=loss_data["index"]).reset_index(drop=True)

# %%
testing = all_data.groupby(["data_name", "model_name", "loss_name"])
testing = testing['iter'].agg(['count'])
testing[testing["count"].values<5]

# %%
testing = all_data.groupby(["data_name", "model_name", "loss_name"])
testing = testing['iter'].agg(['count'])
testing[testing["count"].values>5]

# %%
for d,m,l in over_d.index:
    cheking = all_data[(all_data["data_name"] == d)
               & (all_data["model_name"] == m)
               & (all_data["loss_name"] == l)]
    
    if len(cheking) !=5:
        # print(cheking)
        print(d,m,l)
        print(cheking,"\n")

# %%
all_data.to_csv("all_data_0429.csv")

# %%
# !pwd

# %% [markdown]
# # DATA_LOAD(여기부터 시작)

# %%
new_loss = [ "IoUWithGaussianLoss",
        "BCEWithGaussianLoss",
        "DiceWithGaussianLoss",
        "FocalWithGaussianLoss",
        
        "FocalWithSSIMLoss",
        "IoUWithSSIMLoss" ,
        "DiceWithSSIMLoss"  ,
        "BCEWithSSIMLoss"  ,
        
        "FocalWithContextualLoss" ,
        "BCEWithContextualLoss" ,
        "IoUWithContextualLoss"  ,
        "DiceWithContextualLoss"  ,
        
        "IoUWithTVLoss_tar" ,
        "FocalWithTVLoss_tar"  ,
        "DiceWithTVLoss_tar"  ,
        "BCEWithTVLoss_tar" ,
        
        
        "FocalWithEdgeLoss" ,
        "BCEWithEdgeLoss" ,
        "IoUWithEdgeLoss" ,
        "DiceWithEdgeLoss"]

pres_loss = ['IoULoss', 'DiceLoss', 'BCELoss', 'FocalLoss', 'IoUDiceLoss', 'IoUBCELoss', 'IoUFocalLoss', 
'DiceBCELoss', 'DiceFocalLoss', 'BCEFocalLoss']

all_loss = new_loss + pres_loss
print(f"present_loss_count : {len(pres_loss)}\n present_all_loss : {pres_loss}\n")
print(f"new_loss_count : {len(new_loss)}\n new_loss_loss : {new_loss}\n")
print(f"all_loss_count  : {all_loss} \n all_loss_count : {len(all_loss)} \n ")
# Out:
# present_loss_count : 10
#  present_all_loss : ['IoULoss', 'DiceLoss', 'BCELoss', 'FocalLoss', 'IoUDiceLoss', 'IoUBCELoss', 'IoUFocalLoss', 'DiceBCELoss', 'DiceFocalLoss', 'BCEFocalLoss']
#
# new_loss_count : 20
#  new_loss_loss : ['IoUWithGaussianLoss', 'BCEWithGaussianLoss', 'DiceWithGaussianLoss', 'FocalWithGaussianLoss', 'FocalWithSSIMLoss', 'IoUWithSSIMLoss', 'DiceWithSSIMLoss', 'BCEWithSSIMLoss', 'FocalWithContextualLoss', 'BCEWithContextualLoss', 'IoUWithContextualLoss', 'DiceWithContextualLoss', 'IoUWithTVLoss_tar', 'FocalWithTVLoss_tar', 'DiceWithTVLoss_tar', 'BCEWithTVLoss_tar', 'FocalWithEdgeLoss', 'BCEWithEdgeLoss', 'IoUWithEdgeLoss', 'DiceWithEdgeLoss']
#
# all_loss_count  : ['IoUWithGaussianLoss', 'BCEWithGaussianLoss', 'DiceWithGaussianLoss', 'FocalWithGaussianLoss', 'FocalWithSSIMLoss', 'IoUWithSSIMLoss', 'DiceWithSSIMLoss', 'BCEWithSSIMLoss', 'FocalWithContextualLoss', 'BCEWithContextualLoss', 'IoUWithContextualLoss', 'DiceWithContextualLoss', 'IoUWithTVLoss_tar', 'FocalWithTVLoss_tar', 'DiceWithTVLoss_tar', 'BCEWithTVLoss_tar', 'FocalWithEdgeLoss', 'BCEWithEdgeLoss', 'IoUWithEdgeLoss', 'DiceWithEdgeLoss', 'IoULoss', 'DiceLoss', 'BCELoss', 'FocalLoss', 'IoUDiceLoss', 'IoUBCELoss', 'IoUFocalLoss', 'DiceBCELoss', 'DiceFocalLoss', 'BCEFocalLoss']
#  all_loss_count : 30

# %%
import pandas as pd
import os
all_data = pd.read_csv("./all_data_0511.csv")

# %% [markdown]
# # wound - 완료

# %%
len(all_data[all_data["data_name"] == "wound"]) #/28
# Out:
# 1870

# %%
begin = all_data[all_data["data_name"] == "wound"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    # print(f"\n{m}",groups,"\n")
    # print(f"loss count: {len(groups)}")

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)
            
    # if len(nurack_loss) != 0:
    #     print(f"\n{m}",groups,"\n")
    #     print(f"loss count: {len(groups)}")
    #     print(f"\n누락된 loss :{nurack_loss}\n")

    print(f"\n{m}",groups,"\n")
    print(f"loss count: {len(groups)}")
    print(f"\n누락된 loss :{nurack_loss}\n")
    
    nurack_loss = []
# Out:
# FCBFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# caranet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# UNet++                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# Unet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ESFPNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# DeepLab_V3+                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCN                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonSegNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FAT_Net                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# EMCADNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]

# %% [markdown]
# # Kvasir - 완료

# %%
len(all_data[all_data["data_name"] == "Kvasir-SEG"])
# Out:
# 1870

# %%
begin = all_data[all_data["data_name"] == "Kvasir-SEG"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    print(f"\n{m}",groups,"\n")
    print(f"loss count: {len(groups)}")

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)
    print(f"\n{nurack_loss}\n")
    
    nurack_loss = []
# Out:
# ColonFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# UNet++                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# Unet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# ESFPNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# FCBFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# caranet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# EMCADNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# FCN                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# FAT_Net                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# DeepLab_V3+                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []
#
#
# ColonSegNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# []

# %%
begin = all_data[all_data["data_name"] == "Kvasir-SEG"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    # print(f"\n{m}",groups,"\n")
    # print(f"loss count: {len(groups)}")

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)
            
    if len(nurack_loss) != 0:
        print(f"\n{m}",groups,"\n")
        print(f"loss count: {len(groups)}")
        print(f"\n누락된 loss :{nurack_loss}\n")
    
    nurack_loss = []

# %% [markdown]
# # begin - 완료

# %%
begin_len = len(all_data[all_data["data_name"] == "breast-cancer-benign"])
print(f"총 개수 : {begin_len}")
# Out:
# 총 개수 : 1870

# %%
begin = all_data[all_data["data_name"] == "breast-cancer-benign"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    # print(f"\n{m}",groups,"\n")
    # print(f"loss count: {len(groups)}")

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)
            
    # if len(nurack_loss) != 0:
    print(f"\n{m}",groups,"\n")
    print(f"loss count: {len(groups)}")
    print(f"\n누락된 loss :{nurack_loss}\n")
    
    nurack_loss = []
# Out:
# ColonFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCN                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ESFPNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# caranet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# DeepLab_V3+                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# EMCADNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCBFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# UNet++                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# Unet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonSegNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FAT_Net                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]

# %%
begin = all_data[all_data["data_name"] == "breast-cancer-benign"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    # print(f"\n{m}",groups,"\n")
    # print(f"loss count: {len(groups)}")

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)
            
    if len(nurack_loss) != 0:
        print(f"\n{m}",groups,"\n")
        print(f"loss count: {len(groups)}")
        print(f"\n누락된 loss :{nurack_loss}\n")
    
        nurack_loss = []

# %% [markdown]
# # CVC - 완료

# %%
cvc_len = len(all_data[all_data["data_name"] == "CVC-ClinicDB"])
cvc_len
# Out:
# 1870

# %%
begin = all_data[all_data["data_name"] == "CVC-ClinicDB"]
M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)
            
    print(f"\n{m}",groups,"\n")
    print(f"loss count: {len(groups)}")
    print(f"\n누락된 loss :{nurack_loss}\n")
        
    # if len(nurack_loss) != 0:
    #     print(f"\n{m}",groups,"\n")
    #     print(f"loss count: {len(groups)}")
    #     print(f"\n누락된 loss :{nurack_loss}\n")
    
    nurack_loss = []
# Out:
# ColonFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# UNet++                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# Unet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ESFPNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# DeepLab_V3+                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonSegNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCBFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# caranet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FAT_Net                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# EMCADNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCN                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]

# %% [markdown]
# # malignant - 완료

# %%
cvc_len = len(all_data[all_data["data_name"] == "breast-cancer-malignant"])
cvc_len
# Out:
# 1870

# %%
begin = all_data[all_data["data_name"] == "breast-cancer-malignant"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)

    # if len(nurack_loss) != 0:
    print(f"\n{m}",groups,"\n")
    print(f"loss count: {len(groups)}")
    print(f"\n누락된 loss :{nurack_loss}\n")
    
    nurack_loss = []
# Out:
# ESFPNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCN                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# UNet++                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# Unet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonSegNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# EMCADNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# DeepLab_V3+                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCBFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# caranet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FAT_Net                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]

# %% [markdown]
# # ISIC - 완료

# %%
ISIC_len = len(all_data[all_data["data_name"] == "ISIC"])
ISIC_len
# Out:
# 1870

# %%
begin = all_data[all_data["data_name"] == "ISIC"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)

    
    print(f"\n{m}",groups,"\n")
    print(f"loss count: {len(groups)}")
    print(f"\n누락된 loss :{nurack_loss}\n")
    
    nurack_loss = []
# Out:
# DeepLab_V3+                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# UNet++                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCN                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FCBFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# FAT_Net                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ESFPNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# EMCADNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonFormer                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# ColonSegNet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# caranet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]
#
#
# Unet                          count
# loss_name
# BCEFocalLoss                 5
# BCELoss                      5
# BCEWeightedLoss              5
# BCEWithContextualLoss        5
# BCEWithEdgeLoss              5
# BCEWithGaussianLoss          5
# BCEWithSSIMLoss              5
# BCEWithTVLoss_tar            5
# DiceBCELoss                  5
# DiceFocalLoss                5
# DiceLoss                     5
# DiceWeightedLoss             5
# DiceWithContextualLoss       5
# DiceWithEdgeLoss             5
# DiceWithGaussianLoss         5
# DiceWithSSIMLoss             5
# DiceWithTVLoss_tar           5
# FocalLoss                    5
# FocalWithContextualLoss      5
# FocalWithEdgeLoss            5
# FocalWithGaussianLoss        5
# FocalWithSSIMLoss            5
# FocalWithTVLoss_tar          5
# IoUBCELoss                   5
# IoUDiceLoss                  5
# IoUFocalLoss                 5
# IoULoss                      5
# IoUWeightedLoss              5
# IoUWithContextualLoss        5
# IoUWithEdgeLoss              5
# IoUWithGaussianLoss          5
# IoUWithSSIMLoss              5
# IoUWithTVLoss_tar            5
# IoUWithTV_tar_Loss           5
#
# loss count: 34
#
# 누락된 loss :[]

# %%
begin = all_data[all_data["data_name"] == "ISIC"]

M = begin["model_name"].unique().tolist()
L = begin["loss_name"].unique().tolist()

nurack_loss = []
for m in M:
    m_b = begin[begin["model_name"] == m]

    groups = m_b.groupby(["loss_name"])["iter"].agg(["count"])

    loss = m_b["loss_name"].unique()

    for l in L:
        if l not in loss:
            nurack_loss.append(l)

    if len(nurack_loss) != 0:
        print(f"\n{m}",groups,"\n")
        print(f"loss count: {len(groups)}")
        print(f"\n누락된 loss :{nurack_loss}\n")
    
    nurack_loss = []

# %% [markdown]
# # 모델 - loss

# %%
df = all_data.copy()

# Pivot the table where 'data_name' is the index, 'loss_name' are columns, and values are the mean of other columns
pivot_table_1 = df.pivot_table(index='data_name', columns='loss_name', values='test_dice', aggfunc='mean')

pivot_table_1
# Out:
# loss_name                BCEFocalLoss   BCELoss  BCEWeightedLoss  \
# data_name
# CVC-ClinicDB                 0.828823  0.830083         0.248229
# ISIC                         0.880693  0.880738         0.344368
# Kvasir-SEG                   0.827627  0.827568         0.328406
# breast-cancer-benign         0.761281  0.761965         0.166325
# breast-cancer-malignant      0.674477  0.680637         0.283578
# wound                        0.805501  0.805074         0.126801
#
# loss_name                BCEWithContextualLoss  BCEWithEdgeLoss  \
# data_name
# CVC-ClinicDB                          0.854773         0.851609
# ISIC                                  0.883414         0.883249
# Kvasir-SEG                            0.846930         0.841647
# breast-cancer-benign                  0.781039         0.777884
# breast-cancer-malignant               0.693547         0.690865
# wound                                 0.808494         0.805557
#
# loss_name                BCEWithGaussianLoss  BCEWithSSIMLoss  \
# data_name
# CVC-ClinicDB                        0.851963         0.855865
# ISIC                                0.882829         0.883739
# Kvasir-SEG                          0.840061         0.841128
# breast-cancer-benign                0.774697         0.791460
# breast-cancer-malignant             0.685791         0.686443
# wound                               0.804234         0.806902
#
# loss_name                BCEWithTVLoss_tar  DiceBCELoss  DiceFocalLoss  ...  \
# data_name                                                               ...
# CVC-ClinicDB                      0.853604     0.830845       0.825415  ...
# ISIC                              0.883037     0.880487       0.880142  ...
# Kvasir-SEG                        0.841303     0.827775       0.824275  ...
# breast-cancer-benign              0.789785     0.760941       0.759493  ...
# breast-cancer-malignant           0.689226     0.680281       0.674231  ...
# wound                             0.806088     0.808213       0.808701  ...
#
# loss_name                IoUDiceLoss  IoUFocalLoss   IoULoss  IoUWeightedLoss  \
# data_name
# CVC-ClinicDB                0.826694      0.826725  0.825268         0.847805
# ISIC                        0.881077      0.881133  0.880824         0.883191
# Kvasir-SEG                  0.824621      0.827097  0.826064         0.838478
# breast-cancer-benign        0.759203      0.762105  0.757238         0.773816
# breast-cancer-malignant     0.675610      0.680300  0.677964         0.689300
# wound                       0.808456      0.810037  0.811607         0.810555
#
# loss_name                IoUWithContextualLoss  IoUWithEdgeLoss  \
# data_name
# CVC-ClinicDB                          0.862981         0.863964
# ISIC                                  0.886202         0.885668
# Kvasir-SEG                            0.845658         0.843820
# breast-cancer-benign                  0.812172         0.792890
# breast-cancer-malignant               0.821298         0.696330
# wound                                 0.805901         0.806723
#
# loss_name                IoUWithGaussianLoss  IoUWithSSIMLoss  \
# data_name
# CVC-ClinicDB                        0.846413         0.861686
# ISIC                                0.883198         0.885792
# Kvasir-SEG                          0.839407         0.843391
# breast-cancer-benign                0.773076         0.801518
# breast-cancer-malignant             0.690213         0.690111
# wound                               0.808717         0.806325
#
# loss_name                IoUWithTVLoss_tar  IoUWithTV_tar_Loss
# data_name
# CVC-ClinicDB                      0.800811            0.861266
# ISIC                              0.881157            0.885396
# Kvasir-SEG                        0.839260            0.844917
# breast-cancer-benign              0.731339            0.800212
# breast-cancer-malignant           0.694901            0.693875
# wound                             0.787887            0.807210
#
# [6 rows x 34 columns]

# %%
total_rank_df = pd.DataFrame(data = [0 for _ in range(len(pivot_table_1.columns))],
                             index=[loss for loss in list(pivot_table_1.columns)]).T
data_piv_1= pivot_table_1

ranking = 34
for data in data_piv_1.index:
    for i in range(ranking):
        sort = data_piv_1.loc[data].sort_values(ascending=False)[:]
        ranks = ranking - i
        total_rank_df[data]+=ranks

        # idx = sort.index[i]

        # ranks = ranking - i
        # total_rank_df[idx]+=ranks
        # if i+1 == 1:
        #     total_rank_df[idx]+=ranks
        # elif i+1 == 2:    
        #     total_rank_df[idx]+=ranks
        # elif i+1 == 3:
        #     total_rank_df[idx]+=ranks
        # elif i+1 == 4:    
        #     total_rank_df[idx]+=ranks
        # elif i+1 == 5:
        #     total_rank_df[idx]+=ranks
            
data_piv_1.loc['total'] = list(total_rank_df.loc[0].values)

pivot_table_sort_1 = data_piv_1.copy()
pivot_table_sort_1 = pivot_table_sort_1.T.sort_values(by = 'total',ascending=False).T
pivot_table_sort_1 = pivot_table_sort_1.fillna(0.0)
pivot_table_sort_1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/image/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CVC-ClinicDB'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 10
#       8         sort = data_piv_1.loc[data].sort_values(ascending=False)[:]
#       9         ranks = ranking - i
# ---> 10         total_rank_df[data]+=ranks
#      12         # idx = sort.index[i]
#      13
#      14         # ranks = ranking - i
#    (...)
#      24         # elif i+1 == 5:
#      25         #     total_rank_df[idx]+=ranks
#      27 data_piv_1.loc['total'] = list(total_rank_df.loc[0].values)
#
# File ~/.conda/envs/image/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.conda/envs/image/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'CVC-ClinicDB'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors

# pivot_table_sort_1.columns = pivot_table_sort_1.columns[1:]
testing = pivot_table_sort_1.T.sort_values(by = 'total',ascending=False).copy()
plt.rcdefaults()

nrank = 10 # You can change this value to display up to 'nrank' ranks

# Assume pivot_table is already defined
data = testing.values
data_ind = testing.columns           

# Calculate ranks per row
ranks = np.zeros_like(data, dtype=int)
sorted_indices = np.argsort(-data, axis=0)

for i in range(data.shape[1]):
    ranks[sorted_indices[:,i],i] = np.arange(1, data.shape[0] + 1)

# Transform rank data for color mapping
ranked_data = np.where(ranks <= nrank, ranks, nrank + 1)

# Use ColorBrewer's 'Reds' colormap
cmap = plt.get_cmap('Reds')

# Generate colors for 'nrank' ranks
color_positions = np.linspace(0.8, 0.2, nrank)
colors = [cmap(pos) for pos in color_positions]
colors.append('#F9F9F9')  # Color for 'Others'

# Create the new colormap
new_cmap = mcolors.ListedColormap(colors)

# Set normalization
bounds = np.arange(1, nrank + 3)
norm = mcolors.BoundaryNorm(bounds, new_cmap.N)

# Plot the heatmap
plt.figure(figsize=(7, 7))
ax = sns.heatmap(
    ranked_data,
    annot=data,
    fmt=".4f",
    cmap=new_cmap,
    norm=norm,
    cbar=False,
    xticklabels=testing.columns,
    yticklabels=testing.index,
    linewidths=0.5,
    annot_kws={"size" :9},
)

ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)  # x축 글자 크기
ax.set_yticklabels(ax.get_yticklabels(), fontsize=10, rotation=0)  # y축 글자 크기


plt.tight_layout()       
out_path = f"/project/ahnailab/jsj0414/지역포함_0113/all_result_analysis/result_data_heat.svg"
plt.savefig(out_path, format="svg", bbox_inches="tight")

plt.show()

# %% [markdown]
# #

# %%
pivot_table_sort_1 = data_piv_1.copy()
pivot_table_sort_1 = pivot_table_sort_1.T.sort_values(by = 'total',ascending=False).T
pivot_table_sort_1 = pivot_table_sort_1.fillna(0.0)
pivot_table_sort_1.iloc[-1].values>0

# Pivot the table where 'data_name' is the index, 'loss_name' are columns, and values are the mean of other columns
pivot_table_2 = df.pivot_table(index='model_name', columns='loss_name', values='test_dice', aggfunc='mean')
pivot_table_2 = pivot_table_2.fillna(0.0)
pivot_table_2

total_rank_df = pd.DataFrame(data = [0 for _ in range(len(pivot_table_1.columns))],
                             index=[loss for loss in list(pivot_table_1.columns)]).T
data_piv_1= pivot_table_2

total_rank_df = pd.DataFrame(data = [0 for _ in range(len(pivot_table_1.columns))],
                             index=[loss for loss in list(pivot_table_1.columns)]).T
data_piv_2= pivot_table_2

ranking = 5
for model in data_piv_2.index:
    for i in range(ranking):
        sort = data_piv_2.loc[model].sort_values(ascending=False)[:ranking]
        idx = sort.index[i]

        ranks = ranking - i

        if i+1 == 1:
            total_rank_df[idx]+=ranks
        elif i+1 == 2:    
            total_rank_df[idx]+=ranks
        elif i+1 == 3:
            total_rank_df[idx]+=ranks
        elif i+1 == 4:    
            total_rank_df[idx]+=ranks
        elif i+1 == 5:
            total_rank_df[idx]+=ranks
            
data_piv_2.loc['total'] = list(total_rank_df.loc[0].values)

pivot_table_sort_2 = data_piv_2.copy()
pivot_table_sort_2 = pivot_table_sort_2.T.sort_values(by = 'total',ascending=False).T
pivot_table_sort_2 = pivot_table_sort_2.fillna(0.0)
pivot_table_sort_2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_56319/873828763.py in ?()
#       1 pivot_table_sort_1 = data_piv_1.copy()
# ----> 2 pivot_table_sort_1 = pivot_table_sort_1.T.sort_values(by = 'total',ascending=False).T
#       3 pivot_table_sort_1 = pivot_table_sort_1.fillna(0.0)
#       4 pivot_table_sort_1.iloc[-1].values>0
#       5
#
# ~/.conda/envs/image/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~/.conda/envs/image/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'total'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors

testing = pivot_table_sort_2.T.sort_values(by = 'total',ascending=False).copy()
plt.rcdefaults()

nrank = 5 # You can change this value to display up to 'nrank' ranks

# Assume pivot_table is already defined
data = testing.values
data_ind = testing.columns           

# Calculate ranks per row
ranks = np.zeros_like(data, dtype=int)
sorted_indices = np.argsort(-data, axis=0)

for i in range(data.shape[1]):
    ranks[sorted_indices[:,i],i] = np.arange(1, data.shape[0] + 1)

# Transform rank data for color mapping
ranked_data = np.where(ranks <= nrank, ranks, nrank + 1)

# Use ColorBrewer's 'Reds' colormap
cmap = plt.get_cmap('Reds')

# Generate colors for 'nrank' ranks
color_positions = np.linspace(0.8, 0.2, nrank)
colors = [cmap(pos) for pos in color_positions]
colors.append('#F9F9F9')  # Color for 'Others'

# Create the new colormap
new_cmap = mcolors.ListedColormap(colors)

# Set normalization
bounds = np.arange(1, nrank + 3)
norm = mcolors.BoundaryNorm(bounds, new_cmap.N)

# Plot the heatmap
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    ranked_data,
    annot=data,
    fmt=".4f",
    cmap=new_cmap,
    norm=norm,
    cbar=False,
    xticklabels=testing.columns,
    yticklabels=testing.index,
    linewidths=0.5,
    annot_kws={"size" :9},
)

ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)  # x축 글자 크기
ax.set_yticklabels(ax.get_yticklabels(), fontsize=10, rotation=0)  # y축 글자 크기


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       3 import numpy as np
#       4 import matplotlib.colors as mcolors
# ----> 6 testing = pivot_table_sort_2.T.sort_values(by = 'total',ascending=False).copy()
#       7 plt.rcdefaults()
#       9 nrank = 5 # You can change this value to display up to 'nrank' ranks
#
# NameError: name 'pivot_table_sort_2' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

metrics = ['test_dice', 'test_iou', 'test_precision', 'test_recall']
metrics_len = len(metrics)

W = 61
H = 4

df_new = df[df['model_name'] != 'SegResNet']

for i1 in range(H):   
    fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(25, 10))
    losses = df_new['loss_name'].unique()
    mean_values = []

    for loss in losses:   
        vals = df_new[df_new['loss_name'] == loss][metrics[i1]].dropna()
        mean_val = vals.mean()
        mean_values.append(mean_val)

    # 데이터프레임 생성
    data = pd.DataFrame(data=mean_values, index=list(losses), columns=['value_mean'])
    
    # NaN 제거 (혹시 평균이 NaN인 경우)
    data = data.dropna(subset=['value_mean'])

    colors_1 = sns.color_palette("ch:s=.25,rot=-.25")[0]
    colors_2 = sns.color_palette("ch:s=.25,rot=-.25")[1]

    data['color'] = [colors_1 if loss in ['BCELoss', 'DiceLoss', 'FocalLoss', 'IoULoss'] else colors_2 for loss in data.index]
    data = data.sort_values(by='value_mean', ascending=True)

    # 수평 바 차트 그리기
    axs.barh(data.index, data['value_mean'], color=data['color'])

    # 성능 지표 이름 설정
    m = [metric.replace('test_', '') for metric in metrics]
    reset_met = [m[i][0].upper() + m[i][1:] if m[i] != 'iou' else 'IoU' for i in range(metrics_len)]
    axs.set_title(f"{reset_met[i1]}", fontsize=15)

    # 바 위에 수치 표시
    for j, (value, y) in enumerate(zip(data['value_mean'], data.index)):
        min_loc = data['value_mean'].min()
        max_loc = data['value_mean'].max()
        vas = value - 0.0000001

        axs.tick_params(axis='x', labelsize=13)
        axs.tick_params(axis='y', labelsize=13)
        axs.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.3f}'))
        axs.text(vas, j, f'{value:.4f}', va='center', fontsize=11.5)
        axs.set_xlim(min_loc - 0.01, max_loc + 0.02)

    plt.tight_layout()
    plt.savefig(f"lets_go_paper_{reset_met[i1]}.svg", format="svg", bbox_inches="tight")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

metrics = ['test_dice', 'test_iou', 'test_precision', 'test_recall']
metrics_len = len(metrics)

W = 1
H = 4
fig, axs = plt.subplots(nrows=H, ncols=W, figsize=(25, 40))

df_new = df[df['model_name'] != 'SegResNet']

for i1 in range(H):   
    losses = df_new['loss_name'].unique()
    mean_values = []

    for loss in losses:   
        vals = df_new[df_new['loss_name'] == loss][metrics[i1]].dropna()
        mean_val = vals.mean()
        mean_values.append(mean_val)

    # 데이터프레임 생성
    data = pd.DataFrame(data=mean_values, index=list(losses), columns=['value_mean'])
    
    # NaN 제거 (혹시 평균이 NaN인 경우)
    data = data.dropna(subset=['value_mean'])

    colors_1 = sns.color_palette("ch:s=.25,rot=-.25")[0]
    colors_2 = sns.color_palette("ch:s=.25,rot=-.25")[1]

    data['color'] = [colors_1 if loss in ['BCELoss', 'DiceLoss', 'FocalLoss', 'IoULoss'] else colors_2 for loss in data.index]
    data = data.sort_values(by='value_mean', ascending=True)

    # 수평 바 차트 그리기
    axs[i1].barh(data.index, data['value_mean'], color=data['color'])

    # 성능 지표 이름 설정
    m = [metric.replace('test_', '') for metric in metrics]
    reset_met = [m[i][0].upper() + m[i][1:] if m[i] != 'iou' else 'IoU' for i in range(metrics_len)]
    axs[i1].set_title(f"{reset_met[i1]}", fontsize=15)

    # 바 위에 수치 표시
    for j, (value, y) in enumerate(zip(data['value_mean'], data.index)):
        min_loc = data['value_mean'].min()
        max_loc = data['value_mean'].max()
        vas = value - 0.0000001

        axs[i1].tick_params(axis='x', labelsize=13)
        axs[i1].tick_params(axis='y', labelsize=13)
        axs[i1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.3f}'))
        axs[i1].text(vas, j, f'{value:.4f}', va='center', fontsize=11.5)
        axs[i1].set_xlim(min_loc - 0.01, max_loc + 0.02)

plt.tight_layout()
plt.show()
